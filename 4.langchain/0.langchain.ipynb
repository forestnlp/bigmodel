# %% [markdown]
# # LangChain: 通过组合模块和能力抽象来扩展 LLM 的助手
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
