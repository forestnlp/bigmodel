# %% [markdown]
# # 大模型发展历程

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Chatgpt的诞生历程

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
